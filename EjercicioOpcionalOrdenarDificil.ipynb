# %% [markdown]
# <a href="https://colab.research.google.com/github/aabarzu/Coding-Dojo/blob/main/EjercicioOpcionalOrdenarDificil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
filename = '/content/drive/MyDrive/CodingDojo/DataScience/PandasForDataManipulation/Datos/GDP.csv'
df = pd.read_csv(filename ,skiprows = 4 )

df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
# ...

# %%
df.info() # Para copiar las columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            133 non-null    float64
#  5   1961            133 non-null    float64
#  6   1962            135 non-null    float64
#  7   1963            135 non-null    float64
#  8   1964            135 non-null    float64
#  9   1965            145 non-null    float64
#  10  1966            146 non-null    float64
#  11  1967            149 non-null    float64
#  12  1968            153 non-null    float64
#  13  1969            153 non-null    float64
#  14  1970            162 non-null    float64
#  15  1971            163 non-null    float64
#  16  1972            163 non-null    float64
# ...

# %%
# Melt vuelve las columnas a filas, es como un Group by Pivot funciona a la inversa filas a columnas
# id_vars    = Lista de campos por cuales agrupar , están quedan fijas.
# value_vars = lista de la columnas que se volveran filas

df2 = pd.melt(df, id_vars=['Country Name','Country Code'], value_vars=['1960','1961','1962','1963','1964','1965','1966','1967','1968',
'1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986',
'1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004',
'2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017'] , var_name='Años' ,value_name= 'PIB' )

df2
# Out:
#        Country Name Country Code  Años           PIB
# 0             Aruba          ABW  1960           NaN
# 1       Afghanistan          AFG  1960  5.377778e+08
# 2            Angola          AGO  1960           NaN
# 3           Albania          ALB  1960           NaN
# 4           Andorra          AND  1960           NaN
# ...             ...          ...   ...           ...
# 15307        Kosovo          XKX  2017  7.128691e+09
# 15308   Yemen, Rep.          YEM  2017           NaN
# 15309  South Africa          ZAF  2017  3.494193e+11
# 15310        Zambia          ZMB  2017  2.580867e+10
# 15311      Zimbabwe          ZWE  2017  1.784582e+10
#
# [15312 rows x 4 columns]

# %%
#Cambio nombre de columnas

df2 = df2.rename(columns={'Country Name':'Nombre del País' , 'Country Code':'Código del País'})

df2
# Out:
#       Nombre del País Código del País  Años           PIB
# 0               Aruba             ABW  1960           NaN
# 1         Afghanistan             AFG  1960  5.377778e+08
# 2              Angola             AGO  1960           NaN
# 3             Albania             ALB  1960           NaN
# 4             Andorra             AND  1960           NaN
# ...               ...             ...   ...           ...
# 15307          Kosovo             XKX  2017  7.128691e+09
# 15308     Yemen, Rep.             YEM  2017           NaN
# 15309    South Africa             ZAF  2017  3.494193e+11
# 15310          Zambia             ZMB  2017  2.580867e+10
# 15311        Zimbabwe             ZWE  2017  1.784582e+10
#
# [15312 rows x 4 columns]
