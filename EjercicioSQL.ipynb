# %% [markdown]
# <a href="https://colab.research.google.com/github/aabarzu/Coding-Dojo/blob/main/EjercicioSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# montar datos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# imports
import pandas as pd
from sqlalchemy import create_engine

# %%
# cargar datos: ¡cambia la ruta para que coincida con tu unidad!
school = pd.read_csv('/content/School_Details.csv')
# Asegúrate de que estén cargados correctamente
school.head()
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
# 2         East             S0848
# 3         East             S0190
# 4         East             S0111
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)  Duga Brc
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
# 2  Central Pendam Government Senior Secondary School          SS
# 3  Central Pendam Government Senior Secondary School         JHS
# ...

# %%
# cargar datos: ¡cambia la ruta para que coincida con tu unidad!
# load table 2
facility = pd.read_csv('/content/School_Facility_Details.csv')
facility.head()
# Out:
#   EstablishmentCode                                  EstablishmentName  \
# 0             S1034  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...
# 1             S0516                10TH MILE GOVERNMENT PRIMARY SCHOOL
# 2             S0237             4TH MILE GOVERNMENT JUNIOR HIGH SCHOOL
# 3             S0692                  AAPGAZI GOVERNMENT PRIMARY SCHOOL
# 4             S0374                AARUBOTEY GOVERNMENT PRIMARY SCHOOL
#
#   IsLibraryAvailable  AvailableBooksCount IsFireExtgAvailable  \
# 0      Not Available                    0           Available
# 1      Not Available                    0       Not Available
# 2      Not Available                    0           Available
# 3      Not Available                    0       Not Available
# 4      Not Available                    0           Available
#
#    ExtinguisherCount HOIRoomAvailable IsStaffRoomAvailable  NoofStaffRoom  \
# 0                  1        Available        Not Available              0
# ...

# %%
# crear motor sqlite
engine = create_engine('sqlite:///school.db', echo=True)
# crear conexión con el motor
conn = engine.connect()

# %%
# agregar marco de datos como una tabla en sqlite
sqlite_table = "school_details"
school.to_sql(sqlite_table, conn, if_exists='fail')
# Out:
# 2022-06-15 04:08:27,345 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_details")
# 2022-06-15 04:08:27,347 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-15 04:08:27,355 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_details")
# 2022-06-15 04:08:27,357 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-15 04:08:27,366 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_details (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# 	"PhoneNo" TEXT,
# 	"FaxNo" TEXT,
# 	"EmailID" TEXT,
# 	"Website" TEXT,
# 	"LocatedInRuralOrUrban" TEXT,
# 	"DiseCode" TEXT,
# 	"EstablishedDate" TEXT,
# 	"DistrictHQDistance (in Km)" FLOAT,
# ...

# %%
# agregarel marco de datos como una tabla en sqlite
sqlite_table2 = "school_facility_details"
facility.to_sql(sqlite_table2, conn, if_exists='fail')
# Out:
# 2022-06-15 04:08:33,397 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_facility_details")
# 2022-06-15 04:08:33,400 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-15 04:08:33,407 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_facility_details")
# 2022-06-15 04:08:33,413 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-15 04:08:33,424 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_facility_details (
# 	"index" BIGINT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"IsLibraryAvailable" TEXT,
# 	"AvailableBooksCount" BIGINT,
# 	"IsFireExtgAvailable" TEXT,
# 	"ExtinguisherCount" BIGINT,
# 	"HOIRoomAvailable" TEXT,
# 	"IsStaffRoomAvailable" TEXT,
# 	"NoofStaffRoom" BIGINT,
# 	"IsLockerForStaffAvailable" TEXT,
# 	"IsSportsStoreRoomAvailable" TEXT
# )
#
#
# 2022-06-15 04:08:33,430 INFO sqlalchemy.engine.Engine [no key 0.00520s] ()
# 2022-06-15 04:08:33,445 INFO sqlalchemy.engine.Engine COMMIT
# ...

# %%
def EjecutaSQSL(sql,filas = 5):
  # Escribe tu consulta SQL en esta cadena

  # Lee la consulta sql en pandas para ver los resultados
  df = pd.read_sql_query(sql, engine)
  return df.head(filas)

# %%
def EjecutaSQSLEXEC(sql):
  # Escribe tu consulta SQL en esta cadena

  # Lee la consulta sql en pandas para ver los resultados
  conn.execute(sql)

# %%
# Escribe tu consulta SQL en esta cadena
sql = """
select * from school_details
"""
EjecutaSQSL(sql)
# Out:
# 2022-06-15 01:55:48,585 INFO sqlalchemy.engine.Engine
# select * from school_details
#
# 2022-06-15 01:55:48,588 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
# 2      2         East             S0848
# 3      3         East             S0190
# 4      4         East             S0111
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)  Duga Brc
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# ...

# %%
# Escribe tu consulta SQL en esta cadena
sql = """
select * from school_facility_details
"""
EjecutaSQSL(sql)
# Out:
# 2022-06-15 04:10:30,720 INFO sqlalchemy.engine.Engine
# select * from school_facility_details
#
# 2022-06-15 04:10:30,725 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index EstablishmentCode                                  EstablishmentName  \
# 0      0             S1034  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...
# 1      1             S0516                10TH MILE GOVERNMENT PRIMARY SCHOOL
# 2      2             S0237             4TH MILE GOVERNMENT JUNIOR HIGH SCHOOL
# 3      3             S0692                  AAPGAZI GOVERNMENT PRIMARY SCHOOL
# 4      4             S0374                AARUBOTEY GOVERNMENT PRIMARY SCHOOL
#
#   IsLibraryAvailable  AvailableBooksCount IsFireExtgAvailable  \
# 0      Not Available                    0           Available
# 1      Not Available                    0       Not Available
# 2      Not Available                    0           Available
# 3      Not Available                    0       Not Available
# ...

# %% [markdown]
# **1.- ¿Cuál es el BACDistance promedio (en km)? Renombra la columna resultante como "avg_bac_distancia."**

# %%
# Escribe tu consulta SQL en esta cadena
sql = """
select AVG([BACDistance (in Km)]) as avg_bac_distancia from school_details
"""
EjecutaSQSL(sql)
# Out:
# 2022-06-15 04:12:25,603 INFO sqlalchemy.engine.Engine
# select AVG([BACDistance (in Km)]) as avg_bac_distancia from school_details
#
# 2022-06-15 04:12:25,606 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distancia
# 0          12.681822

# %% [markdown]
# **2.-¿Cuál es el BACDistance promedio (en km) según nivel educativo del colegio?  Ordena los resultados de promedio mayor a promedio menor.**

# %%
# Escribe tu consulta SQL en esta cadena
sql = """
select SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distancia from school_details GROUP BY SchoolLevel ORDER BY avg_bac_distancia ASC
"""
EjecutaSQSL(sql,100)
# Out:
# 2022-06-15 04:14:31,496 INFO sqlalchemy.engine.Engine
# select SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distancia from school_details GROUP BY SchoolLevel ORDER BY avg_bac_distancia ASC
#
# 2022-06-15 04:14:31,508 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distancia
# 0        None                NaN
# 1         LPS           5.368421
# 2         SSS          10.863095
# 3          SS          12.630872
# 4          PS          12.830787
# 5         JHS          13.692647

# %% [markdown]
# **3.-Repite la consulta anterior, pero solo muestra los resultados donde la distancia promedio sea menor a 10 km.**

# %%
# Escribe tu consulta SQL en esta cadena
sql = """
select SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distancia from school_details  GROUP BY SchoolLevel  HAVING avg_bac_distancia < 10 ORDER BY avg_bac_distancia ASC
"""
EjecutaSQSL(sql,100)
# Out:
# 2022-06-15 04:17:50,457 INFO sqlalchemy.engine.Engine
# select SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distancia from school_details  GROUP BY SchoolLevel  HAVING avg_bac_distancia < 10 ORDER BY avg_bac_distancia ASC
#
# 2022-06-15 04:17:50,461 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distancia
# 0         LPS           5.368421

# %% [markdown]
# **4.-Une las dos tablas (detalles de colegios y detalles de instalaciones de los colegios). Comienza mostrando todas las columnas, pero limita las filas resultantes a solo 2.**

# %%
# Escribe tu consulta SQL en esta cadena
sql = """
SELECT * 
FROM school_details AS sd INNER JOIN school_facility_details as sfd
ON sd.EstablishmentCode = sfd.EstablishmentCode;
"""
EjecutaSQSL(sql,100)
# Out:
# 2022-06-15 04:34:40,293 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details AS sd INNER JOIN school_facility_details as sfd
# ON sd.EstablishmentCode = sfd.EstablishmentCode;
#
# 2022-06-15 04:34:40,297 INFO sqlalchemy.engine.Engine [raw sql] ()
#     index DistrictName EstablishmentCode  \
# 0       0         East             S0169
# 1       1         East             S0099
# 2       2         East             S0848
# 3       3         East             S0190
# 4       4         East             S0111
# ..    ...          ...               ...
# 95     95         East             S0506
# 96     96         East             S0208
# 97     97         East             S0942
# 98     98         East             S1219
# 99     99         East             S1248
#
#                                     EstablishmentName      BRCName  \
# 0                BUDANG GOVERNMENT PRIMARY SCHOOL (E)     Duga Brc
# 1   CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL     Duga Brc
# ...

# %%
# Escribe tu consulta SQL en esta cadena
sql = """

SELECT sd.DistrictName, sfd.HOIRoomAvailable 
FROM school_details AS sd INNER JOIN school_facility_details as sfd
ON sd.EstablishmentCode = sfd.EstablishmentCode;


"""
EjecutaSQSL(sql,100)
# Out:
# 2022-06-15 04:39:25,230 INFO sqlalchemy.engine.Engine
#
# SELECT sd.DistrictName, sfd.HOIRoomAvailable
# FROM school_details AS sd INNER JOIN school_facility_details as sfd
# ON sd.EstablishmentCode = sfd.EstablishmentCode;
#
#
#
# 2022-06-15 04:39:25,236 INFO sqlalchemy.engine.Engine [raw sql] ()
#    DistrictName HOIRoomAvailable
# 0          East        Available
# 1          East        Available
# 2          East    Not Available
# 3          East        Available
# 4          East        Available
# ..          ...              ...
# 95         East    Not Available
# 96         East        Available
# 97         East        Available
# 98         East    Not Available
# 99         East    Not Available
#
# [100 rows x 2 columns]
